# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue May 11 23:15:57 2021

@author: ellen degennaro

Purpose:
Generate histogram showing distribution of cells
throughout layers of cortex (laminar distribution)
for cells counted using FIJI software

Input:
    - csv with cell x and y locations and apical/basal surface locations
    - csv with animal info metadata (including blinded filenames)

Output:
    - new data structures containing all data, including normalized y positions
for all cells
    - histograms of laminar position by experimental condition
    
Updates:
5/12/21:
    - store complete dfs for easier plotting
5/16/21:
    - normalize number of cells to total per image (for X-axis)
    - save an output of summary stastistics (for collaborator)
    with means and SEMs for each bin for each condition
5/18/21:
    - add error bars (SEM) to hist - can't do SEM in seaborn, although seaborn is
    nicer, implemented in both seaborn and pyplot (note default bar height is HUGE)
5/19/21:
    - calculate and plot standard deviation instead of SEM
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
############
### load metadata csv
############
BaseDir = '/Users/ellendegenn/Dropbox (MIT)/Walsh Lab/KIF26A/Image Analysis/laminar_quantification/'
OutDir = BaseDir+'210519_out/'
CellDir = BaseDir+'210501_210510_results/'
metafile = 'Master01.csv'

metadf = pd.read_csv(BaseDir+metafile)

# %%
############
### load csvs from folder
############

numfiles = len(metadf)
for current in range(0,numfiles):
    
    #cellfile = 'blind_0001.csv'
    cellfile = metadf['Blinded_Name'][current]+'.csv'

    #now can get cell data
    celldf = pd.read_csv(CellDir+cellfile)

    #let's get all the cells
    allx = celldf['X'][celldf['Counter']==0]
    ally = celldf['Y'][celldf['Counter']==0]

    #check lengths
    if (len(allx)==(np.subtract(len(celldf),2))):
        print('X length ok')
    if (len(ally)==(np.subtract(len(celldf),2))):
        print('Y length ok')

    #now check for the y-position of the apical and basal
    # tissue boundaries - won't know which is which yet
    ybounds = celldf['Y'][celldf['Counter']==1]
    #drop indices
    ybounds = ybounds.reset_index(drop=True)
    #then figure out which is bigger and assign
    
    #confirm that image coordinates are right-side up
    if np.subtract(ybounds[0],ybounds[1]) < 0:
        ay = ybounds[0]
        by = ybounds[1]
    elif np.subtract(ybounds[0],ybounds[1]) > 0:
        ay = ybounds[1]
        by = ybounds[0]

    #now normalize
    #first calculate the maximum y extent and store
    normval = np.subtract(by,ay)
    #now divide all ypositions by this and store
    allnormy = np.divide(ally,normval)
    #now need to flip y value for all
    allnormy = np.subtract(1,allnormy)

    #now check that normalization worked correctly (range: 0-1)
    #print("Verify normalization. Below arrays should be empty")
    #print(allnormy[:][allnormy[:]<0])
    #print(allnormy[:][allnormy[:]>1])
    
    #create a dictionary to store metadata and cell positional data tables
    temp = {'Animal_ID': metadf['Animal_ID'][current],
            'Condition': metadf['Condition'][current],
            'SX_Age': metadf['SX_Age'][current],
            'Sac_Age': metadf['Sac_Age'][current],
            'Apical_Y': ay,
            'Basal_Y': by,
            'Normalization_Value': normval,
            'Total_Num_Cells': len(allx),
            'Cells_X_Pos': allx,
            'Cells_Y_Pos': ally,
            'Norm_Flipped_Cells_Y_Pos': allnormy
           }
    
    #convert to df
    fulldf = pd.DataFrame(temp)

#view to confirm
fulldf
    
#save here
#fulldf.to_csv(OutDir+'FullDF.csv', index=False)
# Out:
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
# X length ok
# Y length ok
#    Animal_ID Condition SX_Age Sac_Age  Apical_Y  Basal_Y  Normalization_Value  \
# 0      8046c  human OE    E13     E17    -0.195  682.803              682.998
# 1      8046c  human OE    E13     E17    -0.195  682.803              682.998
# 2      8046c  human OE    E13     E17    -0.195  682.803              682.998
# 3      8046c  human OE    E13     E17    -0.195  682.803              682.998
# 4      8046c  human OE    E13     E17    -0.195  682.803              682.998
# ..       ...       ...    ...     ...       ...      ...                  ...
# 95     8046c  human OE    E13     E17    -0.195  682.803              682.998
# 96     8046c  human OE    E13     E17    -0.195  682.803              682.998
# 97     8046c  human OE    E13     E17    -0.195  682.803              682.998
# 98     8046c  human OE    E13     E17    -0.195  682.803              682.998
# 99     8046c  human OE    E13     E17    -0.195  682.803              682.998
#
#     Total_Num_Cells  Cells_X_Pos  Cells_Y_Pos  Norm_Flipped_Cells_Y_Pos
# 0               100       87.524      106.279                  0.844393
# 1               100       76.388      163.130                  0.761156
# 2               100       67.010      187.356                  0.725686
# 3               100       69.355      156.879                  0.770308
# 4               100       31.845      136.561                  0.800057
# ..              ...          ...          ...                       ...
# 95              100       78.732      508.537                  0.255434
# 96              100      372.562      528.855                  0.225686
# 97              100      362.403      550.736                  0.193649
# 98              100        6.056      486.656                  0.287471
# 99              100       27.156      646.856                  0.052917
#
# [100 rows x 11 columns]

# %%
############
### plot these histograms with Seaborn
############
#colors from: https://matplotlib.org/stable/gallery/color/named_colors.html

#basic plots without error bars, individually with function

#some global variables for plotting
num_bins = 10
bin_range = (0,1)
stat_plot = 'probability'
#probability normalizes counts so that the sum of the bar heights is 1

def make_hist(data_to_plot, y_vals, plot_color, plot_condition, nb=num_bins, br=bin_range, sp=stat_plot):
    temp_ax = sns.histplot(data = data_to_plot,
                          y = y_vals,
                          bins = nb,
                          binrange = (0,1),
                          stat = 'probability',
                          color = plot_color
                          )
    
    return temp_ax

    #temp_ax.set_ylabel('Laminar Position')
    #temp_ax.set_xlabel('Relative Frequency')
    #temp_ax.set_title(plot_condition)

# %%
# call function defined above to visually inspect each condition

# human over-expression
fig = plt.figure()
ax1 = make_hist(fulldf[fulldf['Condition']=='human OE'],
          'Norm_Flipped_Cells_Y_Pos',
          'mediumblue',
          'Human OE')

# %%
# mCherry scramble control

plt.clf()
fig = plt.figure()
ax2 = make_hist(fulldf[fulldf['Condition']=='mCherry scramble'],
          'Norm_Flipped_Cells_Y_Pos',
          'darkgreen',
          'mCherry Scramble')
fig, ax2 = plt.subplots(1)

# %%
plt.clf()
plt.cla()
# shRNA 1
make_hist(fulldf[fulldf['Condition']=='shRNA1'],
          'Norm_Flipped_Cells_Y_Pos',
          'darksalmon',
         'shRNA1')

# %%
plt.clf()
plt.cla()
# shRNA2
make_hist(fulldf[fulldf['Condition']=='shRNA2'],
          'Norm_Flipped_Cells_Y_Pos',
          'indianred',
          'shRNA2')

# %%
# %matplotlib inline
# shRNA3
make_hist(fulldf[fulldf['Condition']=='shRNA3'],
          'Norm_Flipped_Cells_Y_Pos',
          'maroon',
         'shRNA3')
